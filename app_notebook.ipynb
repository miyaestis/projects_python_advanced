# %%
print("Try me please 😋")  # noqa: T201
# Out:
# Running cells with '.venv (Python 3.12.4)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/projects/empy_python_package - Copy/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
